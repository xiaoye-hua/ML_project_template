# %% [markdown]
# # Package

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Config

# %%
data_dir = '../data/raw_data/iris_cla/train.csv'

# %%
df = pd.read_csv(data_dir)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 410 entries, 0 to 409
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean_radius              410 non-null    float64
#  1   mean_texture             410 non-null    float64
#  2   mean_perimeter           410 non-null    float64
#  3   mean_area                410 non-null    float64
#  4   mean_smoothness          410 non-null    float64
#  5   mean_compactness         410 non-null    float64
#  6   mean_concavity           410 non-null    float64
#  7   mean_concave_points      410 non-null    float64
#  8   mean_symmetry            410 non-null    float64
#  9   mean_fractal_dimension   410 non-null    float64
#  10  radius_error             410 non-null    float64
#  11  texture_error            410 non-null    float64
#  12  perimeter_error          410 non-null    float64
# ...

# %%
for col in df.columns:
    length = len(df[df[col]==0.0])
    print(f"{col}: {length}; [{min(df[col])}, {max(df[col])}]")
# Out:
# mean_radius: 0; [6.981, 28.11]
# mean_texture: 0; [9.71, 39.28]
# mean_perimeter: 0; [43.79, 188.5]
# mean_area: 0; [143.5, 2501.0]
# mean_smoothness: 0; [0.06251, 0.1447]
# mean_compactness: 0; [0.01938, 0.3454]
# mean_concavity: 11; [0.0, 0.4268]
# mean_concave_points: 11; [0.0, 0.2012]
# mean_symmetry: 0; [0.106, 0.304]
# mean_fractal_dimension: 0; [0.049960000000000004, 0.09744]
# radius_error: 0; [0.1115, 2.873]
# texture_error: 0; [0.3602, 4.885]
# perimeter_error: 0; [0.757, 21.98]
# area_error: 0; [7.228, 542.2]
# smoothness_error: 0; [0.001713, 0.03113]
# compactness_error: 0; [0.002252, 0.1006]
# concavity_error: 11; [0.0, 0.396]
# concave_points_error: 11; [0.0, 0.05279]
# symmetry_error: 0; [0.007882, 0.07895]
# fractal_dimension_error: 0; [0.0009683, 0.02984]
# worst_radius: 0; [7.93, 36.04]
# worst_texture: 0; [12.02, 49.54]
# worst_perimeter: 0; [50.41, 251.2]
# worst_area: 0; [185.2, 4254.0]
# worst_smoothness: 0; [0.07117000000000001, 0.2226]
# ...

# %%
X
# Out:
#            0
# 0   6.849198
# 1   8.811997
# 2   7.713801
# 3   4.789413
# 4   2.127036
# 5   9.427730
# 6   9.057254
# 7  -3.673855
# 8  -3.900246
# 9  -8.319055
# 10 -2.442419
# 11  5.277592
# 12  8.119998
# 13 -6.123439
# 14  4.707756
# 15 -6.491442
# 16  8.697656
# 17 -0.952512
# 18  7.188493
# 19  0.657425
# 20  8.911043
# 21  2.332526
# 22 -1.949002
# 23 -5.651273
# 24  7.811431
# 25  7.874553
# 26  8.240171
# 27 -1.835988
# 28  0.215104
# 29 -8.329677
# 30  4.447310
# 31 -4.863964
# 32  3.703126
# 33 -6.662402
# 34  9.978832
# 35  3.446564
# 36  6.258773
# 37 -0.482585
# 38  7.208198
# 39 -1.420397

# %%
# Out:
# [1, 34, 2, 36, 11, 14, 15, 16, 17, 23]

# %%
X
# Out:
#            0
# 0   6.849198
# 1   0.000000
# 2   0.000000
# 3   4.789413
# 4   2.127036
# 5   9.427730
# 6   9.057254
# 7  -3.673855
# 8  -3.900246
# 9  -8.319055
# 10 -2.442419
# 11  0.000000
# 12  8.119998
# 13 -6.123439
# 14  0.000000
# 15  0.000000
# 16  0.000000
# 17  0.000000
# 18  7.188493
# 19  0.657425
# 20  8.911043
# 21  2.332526
# 22 -1.949002
# 23  0.000000
# 24  7.811431
# 25  7.874553
# 26  8.240171
# 27 -1.835988
# 28  0.215104
# 29 -8.329677
# 30  4.447310
# 31 -4.863964
# 32  3.703126
# 33 -6.662402
# 34  0.000000
# 35  3.446564
# 36  0.000000
# 37 -0.482585
# 38  7.208198
# 39 -1.420397
